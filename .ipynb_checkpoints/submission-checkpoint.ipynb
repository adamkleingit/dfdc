# %% [markdown]
# # DeepFake Challenge

# %% [markdown]
# # <a id='0'>Content</a>
#
# - <a href='#game_plan'>Game Plan</a>
# - <a href='#prepare'>Prepare</a>
# - <a href='#extract_frames'>Extract frames to images</a>
# - <a href='#create_data'>Create an ImageDataBunch</a>
# - <a href='#train'>Train Model</a>

# %% [markdown]
# # <a id='game_plan'>Game Plan</a>
# My assumption is that fake videos have frames that are almost undetectable, and frames that are poorly generated. So I imagine a last layer that combines the frames in such a way that if enough frames are most likely fake then the entire video is most likely fake.
#
# Also, that there are very important features in the connection between consecutive frames. Specifically, I want to try to use the delta between frames as an input, since some deep fake videos have these "jumps" of pixels that suddenly appear and disappear.
#
# I'm going to try first to use just the frames, and later try to do manipulations on deltas to see if I can improve.
#
# Also, I feel I need to do some more labelling and manually label some bad frames in the fake videos, that seem to the naked eye more probably fake. Or, this might not be a good idea because then the model won't work well on frames that are faked well.
#
# And lastly, need to somehow separate fake audio from fake video for training purposes, otherwise I feel the model will be confused. Feels like it should just be 2 separate models, and combine their confidence somehow (probably take the one that is more confident about the video being fake)

# %% [markdown]
# ###  <a id="prepare">Prepare</a>

# %% [markdown]
# ##### Install Imports

# %%
import cv2 as cv
import pandas as pd
import numpy as np
import os
import matplotlib
# import matplotlib.pyplot as plt
import matplotlib.pylab as plt
from fastai.vision import *

# %% [markdown]
# ##### Install ffmpeg (only once)

# %%
# !sudo apt update
# !sudo apt install ffmpeg -y

# %% [markdown]
# ##### Constants

# %%
DATA_FOLDER = '../input/deepfake-detection-challenge'
TRAIN_SAMPLE_FOLDER = 'train_sample_videos'
TEST_FOLDER = 'test_videos'
TRAIN_IMAGES_FOLDER = './train'

METADATA_PATH = os.path.join(DATA_FOLDER, TRAIN_SAMPLE_FOLDER, 'metadata.json')

# %% [markdown]
# ### <a id="extract_frames">Extract frames to images</a>
# First I'm going to prepare the data in a nice consumable way and split the videos to images, and prepare a CSV of all frames with labels

# %% [markdown]
# #### Read metadata.json

# %%
metadata_df = pd.read_json(METADATA_PATH).T.reset_index()
metadata_df
# Out:
#               index label  split        original
# 0    aagfhgtpmv.mp4  FAKE  train  vudstovrck.mp4
# 1    aapnvogymq.mp4  FAKE  train  jdubbvfswz.mp4
# 2    abarnvbtwb.mp4  REAL  train            None
# 3    abofeumbvv.mp4  FAKE  train  atvmxvwyns.mp4
# 4    abqwwspghj.mp4  FAKE  train  qzimuostzz.mp4
# ..              ...   ...    ...             ...
# 395  etejaapnxh.mp4  FAKE  train  wtreibcmgm.mp4
# 396  etmcruaihe.mp4  FAKE  train  afoovlsmtx.mp4
# 397  etohcvnzbj.mp4  FAKE  train  bdnaqemxmr.mp4
# 398  eudeqjhdfd.mp4  REAL  train            None
# 399  eukvucdetx.mp4  FAKE  train  gjypopglvi.mp4
#
# [400 rows x 4 columns]

# %% [markdown]
# ##### Display first frame of first video

# %%
first_filename = metadata_df.iloc[0].get('index')
video_file = os.path.join(DATA_FOLDER, TRAIN_SAMPLE_FOLDER, first_filename)
cap = cv.VideoCapture(video_file)
success, image=cap.read()
image = cv.cvtColor(image, cv.COLOR_BGR2RGB)
Image(tensor(image.transpose(2,0,1))).show(figsize=(16,8))

# %% [markdown]
# #### Split all videos to image files (only once)

# %%
# for index, row in metadata_df.iterrows():
#     # get movie filename and label    
#     filename = row.get('index')
#     # create a folder per movie
#     filename_base = filename.split('.')[0]
#     dir_path = os.path.join(TRAIN_IMAGES_FOLDER, filename_base)
#     !mkdir -p {dir_path}
#     print(f'created dir {dir_path}')
#     # split movie to images using ffmpeg and output to folder
#     file_path = os.path.join(DATA_FOLDER, TRAIN_SAMPLE_FOLDER, filename)
#     !ffmpeg -i {file_path} -f image2 {dir_path}/{filename_base}-%03d.jpeg -v quiet
#     image_files = list(os.listdir(dir_path))
#     print(f'ran ffmpeg and created {len(image_files)} images')
# print('finished')
# Out:
# created dir ./train/aagfhgtpmv
# ran ffmpeg and created 300 images
# created dir ./train/aapnvogymq
# ran ffmpeg and created 300 images
# created dir ./train/abarnvbtwb
# ran ffmpeg and created 300 images
# created dir ./train/abofeumbvv
# ran ffmpeg and created 300 images
# created dir ./train/abqwwspghj
# ran ffmpeg and created 300 images
# created dir ./train/acifjvzvpm
# ran ffmpeg and created 300 images
# created dir ./train/acqfdwsrhi
# ran ffmpeg and created 300 images
# created dir ./train/acxnxvbsxk
# ran ffmpeg and created 300 images
# created dir ./train/acxwigylke
# ran ffmpeg and created 298 images
# created dir ./train/aczrgyricp
# ran ffmpeg and created 300 images
# created dir ./train/adhsbajydo
# ran ffmpeg and created 300 images
# created dir ./train/adohikbdaz
# ran ffmpeg and created 300 images
# created dir ./train/adylbeequz
# ran ffmpeg and created 300 images
# created dir ./train/aelfnikyqj
# ran ffmpeg and created 300 images
# created dir ./train/aelzhcnwgf
# ran ffmpeg and created 300 images
# created dir ./train/aettqgevhz
# ran ffmpeg and created 300 images
# created dir ./train/aevrfsexku
# ran ffmpeg and created 300 images
# created dir ./train/afoovlsmtx
# ran ffmpeg and created 300 images
# created dir ./train/agdkmztvby
# ran ffmpeg and created 300 images
# created dir ./train/agqphdxmwt
# ran ffmpeg and created 300 images
# created dir ./train/agrmhtjdlk
# ran ffmpeg and created 300 images
# created dir ./train/ahbweevwpv
# ran ffmpeg and created 300 images
# created dir ./train/ahdbuwqxit
# ran ffmpeg and created 300 images
# created dir ./train/ahfazfbntc
# ran ffmpeg and created 300 images
# created dir ./train/ahqqqilsxt
# ran ffmpeg and created 300 images
# created dir ./train/aipfdnwpoo
# ran ffmpeg and created 300 images
# created dir ./train/ajqslcypsw
# ran ffmpeg and created 300 images
# created dir ./train/ajwpjhrbcv
# ran ffmpeg and created 300 images
# created dir ./train/aklqzsddfl
# ran ffmpeg and created 300 images
# created dir ./train/aknbdpmgua
# ran ffmpeg and created 300 images
# created dir ./train/aknmpoonls
# ran ffmpeg and created 300 images
# created dir ./train/akvmwkdyuv
# ran ffmpeg and created 300 images
# created dir ./train/akxoopqjqz
# ran ffmpeg and created 300 images
# created dir ./train/akzbnazxtz
# ran ffmpeg and created 300 images
# created dir ./train/aladcziidp
# ran ffmpeg and created 298 images
# created dir ./train/alaijyygdv
# ran ffmpeg and created 298 images
# created dir ./train/alninxcyhg
# ran ffmpeg and created 300 images
# created dir ./train/altziddtxi
# ran ffmpeg and created 300 images
# created dir ./train/alvgwypubw
# ran ffmpeg and created 300 images
# created dir ./train/amaivqofda
# ran ffmpeg and created 300 images
# created dir ./train/amowujxmzc
# ran ffmpeg and created 300 images
# created dir ./train/andaxzscny
# ran ffmpeg and created 300 images
# created dir ./train/aneclqfpbt
# ran ffmpeg and created 300 images
# created dir ./train/anpuvshzoo
# ran ffmpeg and created 300 images
# created dir ./train/aorjvbyxhw
# ran ffmpeg and created 300 images
# created dir ./train/apatcsqejh
# ran ffmpeg and created 300 images
# created dir ./train/apgjqzkoma
# ran ffmpeg and created 300 images
# created dir ./train/apogckdfrz
# ran ffmpeg and created 300 images
# created dir ./train/aqpnvjhuzw
# ran ffmpeg and created 300 images
# created dir ./train/arkroixhey
# ran ffmpeg and created 300 images
# created dir ./train/arlmiizoob
# ran ffmpeg and created 300 images
# created dir ./train/arrhsnjqku
# ran ffmpeg and created 300 images
# created dir ./train/asaxgevnnp
# ran ffmpeg and created 300 images
# created dir ./train/asdpeebotb
# ran ffmpeg and created 300 images
# created dir ./train/aslsvlvpth
# ran ffmpeg and created 300 images
# created dir ./train/asmpfjfzif
# ran ffmpeg and created 300 images
# created dir ./train/asvcrfdpnq
# ran ffmpeg and created 300 images
# created dir ./train/atkdltyyen
# ran ffmpeg and created 300 images
# created dir ./train/atvmxvwyns
# ran ffmpeg and created 300 images
# created dir ./train/atxvxouljq
# ran ffmpeg and created 300 images
# created dir ./train/atyntldecu
# ran ffmpeg and created 300 images
# created dir ./train/atzdznmder
# ran ffmpeg and created 300 images
# created dir ./train/aufmsmnoye
# ran ffmpeg and created 300 images
# created dir ./train/augtsuxpzc
# ran ffmpeg and created 300 images
# created dir ./train/avfitoutyn
# ran ffmpeg and created 300 images
# created dir ./train/avgiuextiz
# ran ffmpeg and created 300 images
# created dir ./train/avibnnhwhp
# ran ffmpeg and created 300 images
# created dir ./train/avmjormvsx
# ran ffmpeg and created 300 images
# created dir ./train/avnqydkqjj
# ran ffmpeg and created 300 images
# created dir ./train/avssvvsdhz
# ran ffmpeg and created 300 images
# created dir ./train/avtycwsgyb
# ran ffmpeg and created 300 images
# created dir ./train/avvdgsennp
# ran ffmpeg and created 300 images
# created dir ./train/avywawptfc
# ran ffmpeg and created 300 images
# created dir ./train/awhmfnnjih
# ran ffmpeg and created 300 images
# created dir ./train/awnwkrqibf
# ran ffmpeg and created 300 images
# created dir ./train/awukslzjra
# ran ffmpeg and created 300 images
# created dir ./train/axczxisdtb
# ran ffmpeg and created 300 images
# created dir ./train/axntxmycwd
# ran ffmpeg and created 300 images
# created dir ./train/axoygtekut
# ran ffmpeg and created 298 images
# created dir ./train/axwgcsyphv
# ran ffmpeg and created 300 images
# created dir ./train/axwovszumc
# ran ffmpeg and created 300 images
# created dir ./train/aybgughjxh
# ran ffmpeg and created 300 images
# created dir ./train/aybumesmpk
# ran ffmpeg and created 300 images
# created dir ./train/ayqvfdhslr
# ran ffmpeg and created 300 images
# created dir ./train/aytzyidmgs
# ran ffmpeg and created 300 images
# created dir ./train/azpuxunqyo
# ran ffmpeg and created 300 images
# created dir ./train/azsmewqghg
# ran ffmpeg and created 300 images
# created dir ./train/bahdpoesir
# ran ffmpeg and created 300 images
# created dir ./train/bbhpvrmbse
# ran ffmpeg and created 300 images
# created dir ./train/bbhtdfuqxq
# ran ffmpeg and created 300 images
# created dir ./train/bbvgxeczei
# ran ffmpeg and created 300 images
# created dir ./train/bchnbulevv
# ran ffmpeg and created 300 images
# created dir ./train/bctvsmddgq
# ran ffmpeg and created 300 images
# created dir ./train/bdbhekrrwo
# ran ffmpeg and created 300 images
# created dir ./train/bddjdhzfze
# ran ffmpeg and created 300 images
# created dir ./train/bdgipnyobr
# ran ffmpeg and created 300 images
# created dir ./train/bdnaqemxmr
# ran ffmpeg and created 300 images
# created dir ./train/bdxuhamuqx
# ran ffmpeg and created 300 images
# created dir ./train/beboztfcme
# ran ffmpeg and created 298 images
# created dir ./train/bejhvclboh
# ran ffmpeg and created 300 images
# created dir ./train/benmsfzfaz
# ran ffmpeg and created 300 images
# created dir ./train/beyebyhrph
# ran ffmpeg and created 300 images
# created dir ./train/bffwsjxghk
# ran ffmpeg and created 300 images
# created dir ./train/bgaogsjehq
# ran ffmpeg and created 300 images
# created dir ./train/bggsurpgpr
# ran ffmpeg and created 300 images
# created dir ./train/bghphrsfxf
# ran ffmpeg and created 300 images
# created dir ./train/bgmlwsoamc
# ran ffmpeg and created 300 images
# created dir ./train/bguwlyazau
# ran ffmpeg and created 300 images
# created dir ./train/bgvhtpzknn
# ran ffmpeg and created 300 images
# created dir ./train/bgwmmujlmc
# ran ffmpeg and created 300 images
# created dir ./train/bhaaboftbc
# ran ffmpeg and created 300 images
# created dir ./train/bhbdugnurr
# ran ffmpeg and created 300 images
# created dir ./train/bhpwpydzpo
# ran ffmpeg and created 300 images
# created dir ./train/bhsluedavd
# ran ffmpeg and created 300 images
# created dir ./train/bilnggbxgu
# ran ffmpeg and created 300 images
# created dir ./train/bjjbwsqjir
# ran ffmpeg and created 300 images
# created dir ./train/bjkmjilrxp
# ran ffmpeg and created 300 images
# created dir ./train/bjsmaqefoi
# ran ffmpeg and created 300 images
# created dir ./train/bkmdzhfzfh
# ran ffmpeg and created 300 images
# created dir ./train/bkvetcojbt
# ran ffmpeg and created 300 images
# created dir ./train/bkwxhglwct
# ran ffmpeg and created 300 images
# created dir ./train/blpchvmhxx
# ran ffmpeg and created 300 images
# created dir ./train/blzydqdfem
# ran ffmpeg and created 300 images
# created dir ./train/bmbbkwmxqj
# ran ffmpeg and created 300 images
# created dir ./train/bmehkyanbj
# ran ffmpeg and created 300 images
# created dir ./train/bmhvktyiwp
# ran ffmpeg and created 300 images
# created dir ./train/bmioepcpsx
# ran ffmpeg and created 300 images
# created dir ./train/bmjmjmbglm
# ran ffmpeg and created 300 images
# created dir ./train/bmjzrlszhi
# ran ffmpeg and created 300 images
# created dir ./train/bnbuonyoje
# ran ffmpeg and created 300 images
# created dir ./train/bndybcqhfr
# ran ffmpeg and created 300 images
# created dir ./train/bnjcdrfuov
# ran ffmpeg and created 300 images
# created dir ./train/bntlodcfeg
# ran ffmpeg and created 300 images
# created dir ./train/bofqajtwve
# ran ffmpeg and created 300 images
# created dir ./train/boovltmuwi
# ran ffmpeg and created 300 images
# created dir ./train/bopqhhalml
# ran ffmpeg and created 300 images
# created dir ./train/bourlmzsio
# ran ffmpeg and created 300 images
# created dir ./train/bpapbctoao
# ran ffmpeg and created 300 images
# created dir ./train/bpwzipqtxf
# ran ffmpeg and created 300 images
# created dir ./train/bpxckdzddv
# ran ffmpeg and created 300 images
# created dir ./train/bqdjzqhcft
# ran ffmpeg and created 300 images
# created dir ./train/bqeiblbxtl
# ran ffmpeg and created 300 images
# created dir ./train/bqhtpqmmqp
# ran ffmpeg and created 300 images
# created dir ./train/bqkdbcqjvb
# ran ffmpeg and created 300 images
# created dir ./train/bqnymlsayl
# ran ffmpeg and created 300 images
# created dir ./train/bqqpbzjgup
# ran ffmpeg and created 300 images
# created dir ./train/bqtuuwzdtr
# ran ffmpeg and created 300 images
# created dir ./train/brhalypwoo
# ran ffmpeg and created 300 images
# created dir ./train/brvqtabyxj
# ran ffmpeg and created 300 images
# created dir ./train/brwrlczjvi
# ran ffmpeg and created 300 images
# created dir ./train/bseamdrpbj
# ran ffmpeg and created 300 images
# created dir ./train/bsfmwclnqy
# ran ffmpeg and created 300 images
# created dir ./train/bsqgziaylx
# ran ffmpeg and created 300 images
# created dir ./train/btiysiskpf
# ran ffmpeg and created 300 images
# created dir ./train/btjlfpzbdu
# ran ffmpeg and created 300 images
# created dir ./train/btjwbtsgln
# ran ffmpeg and created 300 images
# created dir ./train/btmsngnqhv
# ran ffmpeg and created 300 images
# created dir ./train/btohlidmru
# ran ffmpeg and created 300 images
# created dir ./train/btugrnoton
# ran ffmpeg and created 300 images
# created dir ./train/btunxncpjh
# ran ffmpeg and created 300 images
# created dir ./train/btxlttbpkj
# ran ffmpeg and created 300 images
# created dir ./train/bulkxhhknf
# ran ffmpeg and created 300 images
# created dir ./train/bvgwelbeof
# ran ffmpeg and created 300 images
# created dir ./train/bvzjkezkms
# ran ffmpeg and created 300 images
# created dir ./train/bweezhfpzp
# ran ffmpeg and created 300 images
# created dir ./train/bwhlgysghg
# ran ffmpeg and created 300 images
# created dir ./train/bwipwzzxxu
# ran ffmpeg and created 300 images
# created dir ./train/bwuwstvsbw
# ran ffmpeg and created 300 images
# created dir ./train/bxzakyopjf
# ran ffmpeg and created 300 images
# created dir ./train/bydaidkpdp
# ran ffmpeg and created 300 images
# created dir ./train/byfenovjnf
# ran ffmpeg and created 300 images
# created dir ./train/byijojkdba
# ran ffmpeg and created 298 images
# created dir ./train/byofowlkki
# ran ffmpeg and created 300 images
# created dir ./train/byqzyxifza
# ran ffmpeg and created 300 images
# created dir ./train/byunigvnay
# ran ffmpeg and created 300 images
# created dir ./train/byyqectxqa
# ran ffmpeg and created 300 images
# created dir ./train/bzmdrafeex
# ran ffmpeg and created 300 images
# created dir ./train/bzythlfnhq
# ran ffmpeg and created 300 images
# created dir ./train/caifxvsozs
# ran ffmpeg and created 300 images
# created dir ./train/caqbrkogkb
# ran ffmpeg and created 300 images
# created dir ./train/cbbibzcoih
# ran ffmpeg and created 300 images
# created dir ./train/cbltdtxglo
# ran ffmpeg and created 300 images
# created dir ./train/ccfoszqabv
# ran ffmpeg and created 300 images
# created dir ./train/ccmonzqfrz
# ran ffmpeg and created 300 images
# created dir ./train/cdaxixbosp
# ran ffmpeg and created 300 images
# created dir ./train/cdbsbdymzd
# ran ffmpeg and created 300 images
# created dir ./train/cdphtzqrvp
# ran ffmpeg and created 300 images
# created dir ./train/cdyakrxkia
# ran ffmpeg and created 300 images
# created dir ./train/cepxysienc
# ran ffmpeg and created 300 images
# created dir ./train/cettndmvzl
# ran ffmpeg and created 300 images
# created dir ./train/ceymbecxnj
# ran ffmpeg and created 300 images
# created dir ./train/cferslmfwh
# ran ffmpeg and created 300 images
# created dir ./train/cffffbcywc
# ran ffmpeg and created 300 images
# created dir ./train/cfxkpiweqt
# ran ffmpeg and created 300 images
# created dir ./train/cfyduhpbps
# ran ffmpeg and created 300 images
# created dir ./train/cglxirfaey
# ran ffmpeg and created 300 images
# created dir ./train/cgvrgibpfo
# ran ffmpeg and created 300 images
# created dir ./train/chtapglbcj
# ran ffmpeg and created 300 images
# created dir ./train/chviwxsfhg
# ran ffmpeg and created 300 images
# created dir ./train/chzieimrwu
# ran ffmpeg and created 298 images
# created dir ./train/ciyoudyhly
# ran ffmpeg and created 300 images
# created dir ./train/cizlkenljw
# ran ffmpeg and created 300 images
# created dir ./train/ckbdwedgmc
# ran ffmpeg and created 300 images
# created dir ./train/ckjaibzfxa
# ran ffmpeg and created 300 images
# created dir ./train/ckkuyewywx
# ran ffmpeg and created 300 images
# created dir ./train/cknyxaqouy
# ran ffmpeg and created 300 images
# created dir ./train/cksanfsjhc
# ran ffmpeg and created 300 images
# created dir ./train/clihsshdkq
# ran ffmpeg and created 300 images
# created dir ./train/clrycekyst
# ran ffmpeg and created 300 images
# created dir ./train/cmbzllswnl
# ran ffmpeg and created 300 images
# created dir ./train/cmxcfkrjiv
# ran ffmpeg and created 300 images
# created dir ./train/cnilkgvfei
# ran ffmpeg and created 300 images
# created dir ./train/coadfnerlk
# ran ffmpeg and created 300 images
# created dir ./train/cobjrlugvp
# ran ffmpeg and created 300 images
# created dir ./train/covdcysmbi
# ran ffmpeg and created 300 images
# created dir ./train/cpjxareypw
# ran ffmpeg and created 300 images
# created dir ./train/cppdvdejkc
# ran ffmpeg and created 298 images
# created dir ./train/cprhtltsjp
# ran ffmpeg and created 300 images
# created dir ./train/cqfugiqupm
# ran ffmpeg and created 300 images
# created dir ./train/cqhngvpgyi
# ran ffmpeg and created 300 images
# created dir ./train/cqrskwiqng
# ran ffmpeg and created 300 images
# created dir ./train/crezycjqyk
# ran ffmpeg and created 300 images
# created dir ./train/crktehraph
# ran ffmpeg and created 300 images
# created dir ./train/crzfebnfgb
# ran ffmpeg and created 300 images
# created dir ./train/cthdnahrkh
# ran ffmpeg and created 300 images
# created dir ./train/ctpqeykqdp
# ran ffmpeg and created 300 images
# created dir ./train/cttqtsjvgn
# ran ffmpeg and created 300 images
# created dir ./train/ctzmavwror
# ran ffmpeg and created 300 images
# created dir ./train/curpwogllm
# ran ffmpeg and created 300 images
# created dir ./train/cuzrgrbvil
# ran ffmpeg and created 300 images
# created dir ./train/cvaksbpssm
# ran ffmpeg and created 300 images
# created dir ./train/cwbacdwrzo
# ran ffmpeg and created 300 images
# created dir ./train/cwqlvzefpg
# ran ffmpeg and created 300 images
# created dir ./train/cwrtyzndpx
# ran ffmpeg and created 300 images
# created dir ./train/cwsbspfzck
# ran ffmpeg and created 300 images
# created dir ./train/cwwandrkus
# ran ffmpeg and created 300 images
# created dir ./train/cxfujlvsuw
# ran ffmpeg and created 300 images
# created dir ./train/cxrfacemmq
# ran ffmpeg and created 300 images
# created dir ./train/cxttmymlbn
# ran ffmpeg and created 300 images
# created dir ./train/cyboodqqyr
# ran ffmpeg and created 300 images
# created dir ./train/cycacemkmt
# ran ffmpeg and created 300 images
# created dir ./train/cyclgfjdrv
# ran ffmpeg and created 300 images
# created dir ./train/cyxlcuyznd
# ran ffmpeg and created 300 images
# created dir ./train/czfunozvwp
# ran ffmpeg and created 300 images
# created dir ./train/czkdanyadc
# ran ffmpeg and created 300 images
# created dir ./train/czmqpxrqoh
# ran ffmpeg and created 300 images
# created dir ./train/dafhtipaml
# ran ffmpeg and created 300 images
# created dir ./train/dakiztgtnw
# ran ffmpeg and created 300 images
# created dir ./train/dakqwktlbi
# ran ffmpeg and created 300 images
# created dir ./train/dbhoxkblzx
# ran ffmpeg and created 300 images
# created dir ./train/dbhrpizyeq
# ran ffmpeg and created 298 images
# created dir ./train/dbnygxtwek
# ran ffmpeg and created 300 images
# created dir ./train/dboxtiehng
# ran ffmpeg and created 300 images
# created dir ./train/dbtbbhakdv
# ran ffmpeg and created 300 images
# created dir ./train/dbzcqmxzaj
# ran ffmpeg and created 300 images
# created dir ./train/dbzpcjntve
# ran ffmpeg and created 300 images
# created dir ./train/dcamvmuors
# ran ffmpeg and created 300 images
# created dir ./train/dcuiiorugd
# ran ffmpeg and created 300 images
# created dir ./train/ddepeddixj
# ran ffmpeg and created 298 images
# created dir ./train/ddhfabwpuz
# ran ffmpeg and created 300 images
# created dir ./train/ddjggcasdw
# ran ffmpeg and created 300 images
# created dir ./train/ddpvuimigj
# ran ffmpeg and created 300 images
# created dir ./train/ddqccgmtka
# ran ffmpeg and created 300 images
# created dir ./train/degpbqvcay
# ran ffmpeg and created 300 images
# created dir ./train/deywhkarol
# ran ffmpeg and created 300 images
# created dir ./train/deyyistcrd
# ran ffmpeg and created 300 images
# created dir ./train/dfbpceeaox
# ran ffmpeg and created 300 images
# created dir ./train/dgmevclvzy
# ran ffmpeg and created 300 images
# created dir ./train/dgxrqjdomn
# ran ffmpeg and created 300 images
# created dir ./train/dgzklxjmix
# ran ffmpeg and created 300 images
# created dir ./train/dhcndnuwta
# ran ffmpeg and created 300 images
# created dir ./train/dhcselezer
# ran ffmpeg and created 300 images
# created dir ./train/dhevettufk
# ran ffmpeg and created 298 images
# created dir ./train/dhjmzhrcav
# ran ffmpeg and created 300 images
# created dir ./train/dhkwmjxwrn
# ran ffmpeg and created 300 images
# created dir ./train/dhoqofwoxa
# ran ffmpeg and created 300 images
# created dir ./train/dhxctgyoqj
# ran ffmpeg and created 300 images
# created dir ./train/diomeixhrg
# ran ffmpeg and created 300 images
# created dir ./train/diopzaywor
# ran ffmpeg and created 300 images
# created dir ./train/diqraixiov
# ran ffmpeg and created 300 images
# created dir ./train/diuzrpqjli
# ran ffmpeg and created 300 images
# created dir ./train/djvtbgwdcc
# ran ffmpeg and created 300 images
# created dir ./train/djvutyvaio
# ran ffmpeg and created 300 images
# created dir ./train/djxdyjopjd
# ran ffmpeg and created 300 images
# created dir ./train/dkdwxmtpuo
# ran ffmpeg and created 300 images
# created dir ./train/dkhlttuvmx
# ran ffmpeg and created 300 images
# created dir ./train/dkrvorliqc
# ran ffmpeg and created 300 images
# created dir ./train/dkuayagnmc
# ran ffmpeg and created 300 images
# created dir ./train/dkwjwbwgey
# ran ffmpeg and created 300 images
# created dir ./train/dkzvdrzcnr
# ran ffmpeg and created 300 images
# created dir ./train/dlpoieqvfb
# ran ffmpeg and created 300 images
# created dir ./train/dlrsbscitn
# ran ffmpeg and created 300 images
# created dir ./train/dnexlwbcxq
# ran ffmpeg and created 300 images
# created dir ./train/dnhvalzvrt
# ran ffmpeg and created 300 images
# created dir ./train/dntkzzzcdh
# ran ffmpeg and created 300 images
# created dir ./train/dnyvfblxpm
# ran ffmpeg and created 300 images
# created dir ./train/doanjploai
# ran ffmpeg and created 300 images
# created dir ./train/dofusvhnib
# ran ffmpeg and created 300 images
# created dir ./train/dozyddhild
# ran ffmpeg and created 298 images
# created dir ./train/dptbnjnkdg
# ran ffmpeg and created 300 images
# created dir ./train/dptrzdvwpg
# ran ffmpeg and created 300 images
# created dir ./train/dqnyszdong
# ran ffmpeg and created 300 images
# created dir ./train/dqppxmoqdl
# ran ffmpeg and created 300 images
# created dir ./train/dqqtjcryjv
# ran ffmpeg and created 300 images
# created dir ./train/dqswpjoepo
# ran ffmpeg and created 300 images
# created dir ./train/dqzreruvje
# ran ffmpeg and created 300 images
# created dir ./train/drcyabprvt
# ran ffmpeg and created 300 images
# created dir ./train/drgjzlxzxj
# ran ffmpeg and created 300 images
# created dir ./train/drsakwyvqv
# ran ffmpeg and created 300 images
# created dir ./train/drtbksnpol
# ran ffmpeg and created 300 images
# created dir ./train/dsdoseflas
# ran ffmpeg and created 300 images
# created dir ./train/dsgpbgsrdm
# ran ffmpeg and created 300 images
# created dir ./train/dsjbknkujw
# ran ffmpeg and created 300 images
# created dir ./train/dsndhujjjb
# ran ffmpeg and created 300 images
# created dir ./train/dtbpmdqvao
# ran ffmpeg and created 300 images
# created dir ./train/dtocdfbwca
# ran ffmpeg and created 300 images
# created dir ./train/dubiroskqn
# ran ffmpeg and created 300 images
# created dir ./train/dulanfulol
# ran ffmpeg and created 300 images
# created dir ./train/duvyaxbzvp
# ran ffmpeg and created 300 images
# created dir ./train/duycddgtrl
# ran ffmpeg and created 300 images
# created dir ./train/duzuusuajr
# ran ffmpeg and created 300 images
# created dir ./train/dvakowbgbt
# ran ffmpeg and created 300 images
# created dir ./train/dvumqqhoac
# ran ffmpeg and created 300 images
# created dir ./train/dwediigjit
# ran ffmpeg and created 300 images
# created dir ./train/dxbqjxrhin
# ran ffmpeg and created 300 images
# created dir ./train/dxuliowugt
# ran ffmpeg and created 300 images
# created dir ./train/dxuplhwvig
# ran ffmpeg and created 300 images
# created dir ./train/dzieklokdr
# ran ffmpeg and created 300 images
# created dir ./train/dzqwgqewhu
# ran ffmpeg and created 300 images
# created dir ./train/dzvyfiarrq
# ran ffmpeg and created 300 images
# created dir ./train/dzwkmcwkwl
# ran ffmpeg and created 300 images
# created dir ./train/dzyuwjkjui
# ran ffmpeg and created 300 images
# created dir ./train/eahlqmfvtj
# ran ffmpeg and created 300 images
# created dir ./train/eajlrktemq
# ran ffmpeg and created 300 images
# created dir ./train/ebchwmwayp
# ran ffmpeg and created 300 images
# created dir ./train/ebebgmtlcu
# ran ffmpeg and created 300 images
# created dir ./train/ebeknhudxq
# ran ffmpeg and created 300 images
# created dir ./train/ebkzwjgjhq
# ran ffmpeg and created 300 images
# created dir ./train/ebywfrmhtd
# ran ffmpeg and created 300 images
# created dir ./train/eckvhdusax
# ran ffmpeg and created 300 images
# created dir ./train/ecnihjlfyt
# ran ffmpeg and created 300 images
# created dir ./train/ecujsjhscd
# ran ffmpeg and created 300 images
# created dir ./train/ecuvtoltue
# ran ffmpeg and created 300 images
# created dir ./train/ecwaxgutkc
# ran ffmpeg and created 300 images
# created dir ./train/eczrseixwq
# ran ffmpeg and created 300 images
# created dir ./train/edyncaijwx
# ran ffmpeg and created 300 images
# created dir ./train/eebrkicpry
# ran ffmpeg and created 300 images
# created dir ./train/eebserckhh
# ran ffmpeg and created 300 images
# created dir ./train/eejswgycjc
# ran ffmpeg and created 300 images
# created dir ./train/eekozbeafq
# ran ffmpeg and created 300 images
# created dir ./train/eepezmygaq
# ran ffmpeg and created 300 images
# created dir ./train/eeyhxisdfh
# ran ffmpeg and created 300 images
# created dir ./train/efdyrflcpg
# ran ffmpeg and created 300 images
# created dir ./train/efwfxwwlbw
# ran ffmpeg and created 300 images
# created dir ./train/egbbcxcuqy
# ran ffmpeg and created 300 images
# created dir ./train/eggbjzxnmg
# ran ffmpeg and created 300 images
# created dir ./train/egghxjjmfg
# ran ffmpeg and created 300 images
# created dir ./train/ehbnclaukr
# ran ffmpeg and created 300 images
# created dir ./train/ehccixxzoe
# ran ffmpeg and created 300 images
# created dir ./train/ehdkmxgtxh
# ran ffmpeg and created 300 images
# created dir ./train/ehevsxtecd
# ran ffmpeg and created 300 images
# created dir ./train/ehfiekigla
# ran ffmpeg and created 300 images
# created dir ./train/ehieahnhte
# ran ffmpeg and created 300 images
# created dir ./train/ehtdtkmmli
# ran ffmpeg and created 300 images
# created dir ./train/eiriyukqqy
# ran ffmpeg and created 300 images
# created dir ./train/eivxffliio
# ran ffmpeg and created 300 images
# created dir ./train/eiwopxzjfn
# ran ffmpeg and created 300 images
# created dir ./train/eixwxvxbbn
# ran ffmpeg and created 300 images
# created dir ./train/ejkqesyvam
# ran ffmpeg and created 300 images
# created dir ./train/ekcrtigpab
# ran ffmpeg and created 300 images
# created dir ./train/ekhacizpah
# ran ffmpeg and created 300 images
# created dir ./train/ekkdjkirzq
# ran ffmpeg and created 300 images
# created dir ./train/elginszwtk
# ran ffmpeg and created 300 images
# created dir ./train/ellavthztb
# ran ffmpeg and created 300 images
# created dir ./train/elvvackpjh
# ran ffmpeg and created 300 images
# created dir ./train/emaalmsonj
# ran ffmpeg and created 300 images
# created dir ./train/emfbhytfhc
# ran ffmpeg and created 300 images
# created dir ./train/emgjphonqb
# ran ffmpeg and created 300 images
# created dir ./train/ensyyivobf
# ran ffmpeg and created 300 images
# created dir ./train/eoewqcpbgt
# ran ffmpeg and created 300 images
# created dir ./train/eprybmbpba
# ran ffmpeg and created 300 images
# created dir ./train/epymyyiblu
# ran ffmpeg and created 300 images
# created dir ./train/eqjscdagiv
# ran ffmpeg and created 300 images
# created dir ./train/eqnoqyfquo
# ran ffmpeg and created 300 images
# created dir ./train/eqvuznuwsa
# ran ffmpeg and created 300 images
# created dir ./train/erlvuvjsjf
# ran ffmpeg and created 300 images
# created dir ./train/erqgqacbqe
# ran ffmpeg and created 300 images
# created dir ./train/errocgcham
# ran ffmpeg and created 300 images
# created dir ./train/esckbnkkvb
# ran ffmpeg and created 300 images
# created dir ./train/esgftaficx
# ran ffmpeg and created 300 images
# created dir ./train/esnntzzajv
# ran ffmpeg and created 298 images
# created dir ./train/esxrvsgpvb
# ran ffmpeg and created 300 images
# created dir ./train/esyhwdfnxs
# ran ffmpeg and created 300 images
# created dir ./train/esyrimvzsa
# ran ffmpeg and created 300 images
# created dir ./train/etdcqxabww
# ran ffmpeg and created 300 images
# created dir ./train/etejaapnxh
# ran ffmpeg and created 300 images
# created dir ./train/etmcruaihe
# ran ffmpeg and created 300 images
# created dir ./train/etohcvnzbj
# ran ffmpeg and created 300 images
# created dir ./train/eudeqjhdfd
# ran ffmpeg and created 300 images
# created dir ./train/eukvucdetx
# ran ffmpeg and created 300 images
# finished

# %% [markdown]
# ### <a id="create_data">Create an ImageDataBunch</a>

# %%
training_set = []
for index, row in metadata_df.iterrows():
    # iterate over created images and add them to training_set
    filename = row.get('index')
    label = row.get('label')
    # create a folder per movie
    filename_base = filename.split('.')[0]
    dir_path = os.path.join(TRAIN_IMAGES_FOLDER, filename_base)
    image_files = list(os.listdir(dir_path))
    image_files = map(lambda image_filename: os.path.join(filename_base, image_filename), image_files)
    image_files = map(lambda image_path: (image_path, label), image_files)
    image_files = list(image_files)
    training_set += image_files
train_df = DataFrame.from_records(training_set, columns=("name", "label"))
train_df
# Out:
#                                   name label
# 0       aagfhgtpmv/aagfhgtpmv-106.jpeg  FAKE
# 1       aagfhgtpmv/aagfhgtpmv-256.jpeg  FAKE
# 2       aagfhgtpmv/aagfhgtpmv-132.jpeg  FAKE
# 3       aagfhgtpmv/aagfhgtpmv-142.jpeg  FAKE
# 4       aagfhgtpmv/aagfhgtpmv-003.jpeg  FAKE
# ...                                ...   ...
# 119969  eukvucdetx/eukvucdetx-293.jpeg  FAKE
# 119970  eukvucdetx/eukvucdetx-178.jpeg  FAKE
# 119971  eukvucdetx/eukvucdetx-229.jpeg  FAKE
# 119972  eukvucdetx/eukvucdetx-072.jpeg  FAKE
# 119973  eukvucdetx/eukvucdetx-055.jpeg  FAKE
#
# [119974 rows x 2 columns]

# %%
np.random.seed(0)
data = (ImageDataBunch
    .from_df(df=train_df, path=TRAIN_IMAGES_FOLDER)
    .split_by_rand_pct()
    .label_from_df()
    .transform(get_transforms(), size=128)
    .databunch(bs=64)
    .normalize(imagenet_stats))
data
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/fastai/basic_data.py:271: UserWarning: It's not possible to collate samples of your dataset together in a batch.
# Shapes of the inputs/targets:
# [[torch.Size([3, 1080, 1920]), torch.Size([3, 1080, 1920]), torch.Size([3, 1080, 1920]), torch.Size([3, 1080, 1920]), torch.Size([3, 1080, 1920]), torch.Size([3, 1080, 1920]), torch.Size([3, 1080, 1920]), torch.Size([3, 1080, 1920]), torch.Size([3, 1080, 1920]), torch.Size([3, 1920, 1080]), torch.Size([3, 1080, 1920]), torch.Size([3, 1080, 1920]), torch.Size([3, 1080, 1920]), torch.Size([3, 1080, 1920]), torch.Size([3, 1080, 1920]), torch.Size([3, 1080, 1920]), torch.Size([3, 1080, 1920]), torch.Size([3, 1080, 1920]), torch.Size([3, 1080, 1920]), torch.Size([3, 1920, 1080]), torch.Size([3, 1080, 1920]), torch.Size([3, 1080, 1920]), torch.Size([3, 1080, 1920]), torch.Size([3, 1080, 1920]), torch.Size([3, 1080, 1920]), torch.Size([3, 1080, 1920]), torch.Size([3, 1080, 1920]), torch.Size([3, 1080, 1920]), torch.Size([3, 1080, 1920]), torch.Size([3, 1080, 1920]), torch.Size([3, 1080, 1920]), torch.Size([3, 1080, 1920]), torch.Size([3, 1080, 1920]), torch.Size([3, 1080, 1920]), torch.Size([3, 1080, 1920]), torch.Size([3, 1920, 1080]), torch.Size([3, 1080, 1920]), torch.Size([3, 1080, 1920]), torch.Size([3, 1080, 1920]), torch.Size([3, 1080, 1920]), torch.Size([3, 1080, 1920]), torch.Size([3, 1080, 1920]), torch.Size([3, 1080, 1920]), torch.Size([3, 1080, 1920]), torch.Size([3, 1080, 1920]), torch.Size([3, 1080, 1920]), torch.Size([3, 1080, 1920]), torch.Size([3, 1080, 1920]), torch.Size([3, 1080, 1920]), torch.Size([3, 1080, 1920]), torch.Size([3, 1080, 1920]), torch.Size([3, 1080, 1920]), torch.Size([3, 1080, 1920]), torch.Size([3, 1080, 1920]), torch.Size([3, 1080, 1920]), torch.Size([3, 1080, 1920]), torch.Size([3, 1080, 1920]), torch.Size([3, 1080, 1920]), torch.Size([3, 1080, 1920]), torch.Size([3, 1080, 1920]), torch.Size([3, 1080, 1920]), torch.Size([3, 1080, 1920]), torch.Size([3, 1080, 1920]), torch.Size([3, 1080, 1920])], [(), (), (), (), (), (), (), (), (), (), (), (), (), (), (), (), (), (), (), (), (), (), (), (), (), (), (), (), (), (), (), (), (), (), (), (), (), (), (), (), (), (), (), (), (), (), (), (), (), (), (), (), (), (), (), (), (), (), (), (), (), (), (), ()]]
#   warn(message)
# You can deactivate this warning by passing `no_check=True`.
# ImageDataBunch;
#
# Train: LabelList (76784 items)
# x: ImageList
# Image (3, 128, 128),Image (3, 128, 128),Image (3, 128, 128),Image (3, 128, 128),Image (3, 128, 128)
# y: CategoryList
# FAKE,FAKE,FAKE,FAKE,FAKE
# Path: train;
#
# Valid: LabelList (19196 items)
# x: ImageList
# Image (3, 128, 128),Image (3, 128, 128),Image (3, 128, 128),Image (3, 128, 128),Image (3, 128, 128)
# y: CategoryList
# FAKE,FAKE,REAL,FAKE,REAL
# Path: train;
#
# Test: None

# %% [markdown]
# ### <a id="train">Train a regular CNN learner</a>

# %%
learn = cnn_learner(data, models.resnet34, model_dir='../models')
learn
# Out:
# Learner(data=ImageDataBunch;
#
# Train: LabelList (76784 items)
# x: ImageList
# Image (3, 128, 128),Image (3, 128, 128),Image (3, 128, 128),Image (3, 128, 128),Image (3, 128, 128)
# y: CategoryList
# FAKE,FAKE,FAKE,FAKE,FAKE
# Path: train;
#
# Valid: LabelList (19196 items)
# x: ImageList
# Image (3, 128, 128),Image (3, 128, 128),Image (3, 128, 128),Image (3, 128, 128),Image (3, 128, 128)
# y: CategoryList
# FAKE,FAKE,REAL,FAKE,REAL
# Path: train;
#
# Test: None, model=Sequential(
#   (0): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#     (3): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (4): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (2): BasicBlock(
#         (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (5): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (downsample): Sequential(
#           (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (2): BasicBlock(
#         (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (3): BasicBlock(
#         (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (6): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (downsample): Sequential(
#           (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (2): BasicBlock(
#         (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (3): BasicBlock(
#         (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (4): BasicBlock(
#         (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (5): BasicBlock(
#         (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (7): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (downsample): Sequential(
#           (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (2): BasicBlock(
#         (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#   )
#   (1): Sequential(
#     (0): AdaptiveConcatPool2d(
#       (ap): AdaptiveAvgPool2d(output_size=1)
#       (mp): AdaptiveMaxPool2d(output_size=1)
#     )
#     (1): Flatten()
#     (2): BatchNorm1d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (3): Dropout(p=0.25, inplace=False)
#     (4): Linear(in_features=1024, out_features=512, bias=True)
#     (5): ReLU(inplace=True)
#     (6): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (7): Dropout(p=0.5, inplace=False)
#     (8): Linear(in_features=512, out_features=2, bias=True)
#   )
# ), opt_func=functools.partial(<class 'torch.optim.adam.Adam'>, betas=(0.9, 0.99)), loss_func=FlattenedLoss of CrossEntropyLoss(), metrics=[], true_wd=True, bn_wd=True, wd=0.01, train_bn=True, path=PosixPath('train'), model_dir='../models', callback_fns=[functools.partial(<class 'fastai.basic_train.Recorder'>, add_time=True, silent=False)], callbacks=[], layer_groups=[Sequential(
#   (0): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU(inplace=True)
#   (3): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (4): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (5): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU(inplace=True)
#   (7): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (8): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (9): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (10): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (11): ReLU(inplace=True)
#   (12): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (13): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (14): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (15): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (16): ReLU(inplace=True)
#   (17): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (18): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (19): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#   (20): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (21): ReLU(inplace=True)
#   (22): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (23): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (24): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#   (25): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (26): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (27): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (28): ReLU(inplace=True)
#   (29): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (30): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (31): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (32): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (33): ReLU(inplace=True)
#   (34): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (35): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (36): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (37): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (38): ReLU(inplace=True)
#   (39): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (40): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# ), Sequential(
#   (0): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#   (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU(inplace=True)
#   (3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (4): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (5): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#   (6): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (7): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (8): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (9): ReLU(inplace=True)
#   (10): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (11): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (12): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (13): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (14): ReLU(inplace=True)
#   (15): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (16): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (17): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (18): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (19): ReLU(inplace=True)
#   (20): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (21): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (22): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (23): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (24): ReLU(inplace=True)
#   (25): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (26): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (27): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (28): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (29): ReLU(inplace=True)
#   (30): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (31): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (32): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#   (33): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (34): ReLU(inplace=True)
#   (35): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (36): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (37): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#   (38): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (39): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (40): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (41): ReLU(inplace=True)
#   (42): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (43): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (44): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (45): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (46): ReLU(inplace=True)
#   (47): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (48): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# ), Sequential(
#   (0): AdaptiveAvgPool2d(output_size=1)
#   (1): AdaptiveMaxPool2d(output_size=1)
#   (2): Flatten()
#   (3): BatchNorm1d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (4): Dropout(p=0.25, inplace=False)
#   (5): Linear(in_features=1024, out_features=512, bias=True)
#   (6): ReLU(inplace=True)
#   (7): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (8): Dropout(p=0.5, inplace=False)
#   (9): Linear(in_features=512, out_features=2, bias=True)
# )], add_time=True, silent=False)

# %%
# learn.lr_find()
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
# learn.recorder.plot()

# %%
lr = 0.01
learn.fit_one_cycle(4, slice(lr))
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='4', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/4 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='365' class='' max='1199', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       30.44% [365/1199 11:18<25:49 0.5346]
#     </div>

# %% [markdown]
# ### Try to use some labelled frames and only train on those

# %% [markdown]
# ### Try to visualize the difference between the original and the fake video
# Just to get a better intuition about the kind of manipulations we are trying to isolate
